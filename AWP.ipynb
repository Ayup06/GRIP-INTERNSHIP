# %%
"""Importing libraries"""
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
""" Importing the csv file , reading it , cleaning it and analysing it"""
df = pd.read_csv("movies.csv")
print(df.info())
'dataset has 7668 rows'
print(df.head(10))
# Analysis of numerical values
df1 = df.describe().T
print(df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     7668 non-null   object
#  1   rating   7591 non-null   object
#  2   genre    7668 non-null   object
#  3   year     7668 non-null   int64
#  4   score    7665 non-null   float64
#  5   votes    7665 non-null   float64
#  6   country  7665 non-null   object
#  7   budget   5497 non-null   float64
#  8   gross    7479 non-null   float64
#  9   company  7651 non-null   object
#  10  runtime  7664 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 659.1+ KB
# None
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#    score      votes         country      budget        gross  \
# 0    8.4   927000.0  United Kingdom  19000000.0   46998772.0
# 1    5.8    65000.0   United States   4500000.0   58853106.0
# 2    8.7  1200000.0   United States  18000000.0  538375067.0
# 3    7.7   221000.0   United States   3500000.0   83453539.0
# 4    7.3   108000.0   United States   6000000.0   39846344.0
# 5    6.4   123000.0   United States    550000.0   39754601.0
# 6    7.9   188000.0   United States  27000000.0  115229890.0
# 7    8.2   330000.0   United States  18000000.0   23402427.0
# 8    6.8   101000.0   United States  54000000.0  108185706.0
# 9    7.0    10000.0   United States  10000000.0   15795189.0
#
#                         company  runtime
# 0                  Warner Bros.    146.0
# 1             Columbia Pictures    104.0
# 2                     Lucasfilm    124.0
# 3            Paramount Pictures     88.0
# 4                Orion Pictures     98.0
# 5            Paramount Pictures     95.0
# 6            Universal Pictures    133.0
# 7  Chartoff-Winkler Productions    129.0
# 8                Dovemead Films    127.0
# 9                United Artists    100.0
#           count          mean           std     min         25%         50%  \
# year     7668.0  2.000405e+03  1.115351e+01  1980.0      1991.0      2000.0
# score    7665.0  6.390411e+00  9.688416e-01     1.9         5.8         6.5
# votes    7665.0  8.810850e+04  1.633238e+05     7.0      9100.0     33000.0
# budget   5497.0  3.558988e+07  4.145730e+07  3000.0  10000000.0  20500000.0
# gross    7479.0  7.850054e+07  1.657251e+08   309.0   4532055.5  20205757.0
# runtime  7664.0  1.072616e+02  1.858125e+01    55.0        95.0       104.0
#
#                 75%           max
# year         2010.0  2.020000e+03
# score           7.1  9.300000e+00
# votes       93000.0  2.400000e+06
# budget   45000000.0  3.560000e+08
# gross    76016691.5  2.847246e+09
# runtime       116.0  3.660000e+02

# %%
# deleting rows with empty cells
df.dropna(inplace=True)
print(df.info())
'After deleting empty cells , remanining number of rows are 5421'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5421 entries, 0 to 7652
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5421 non-null   object
#  1   rating   5421 non-null   object
#  2   genre    5421 non-null   object
#  3   year     5421 non-null   int64
#  4   score    5421 non-null   float64
#  5   votes    5421 non-null   float64
#  6   country  5421 non-null   object
#  7   budget   5421 non-null   float64
#  8   gross    5421 non-null   float64
#  9   company  5421 non-null   object
#  10  runtime  5421 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 508.2+ KB
# None
# 'After deleting empty cells , remanining number of rows are 5421'

# %%
# Changing data type of columns
df["score"] = df["score"].astype("int64")
df["votes"] = df["votes"].astype("int64")
df["budget"] = df["budget"].astype("int64")
df["gross"] = df["gross"].astype("int64")
df["runtime"] = df["runtime"].astype("int64")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5421 entries, 0 to 7652
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5421 non-null   object
#  1   rating   5421 non-null   object
#  2   genre    5421 non-null   object
#  3   year     5421 non-null   int64
#  4   score    5421 non-null   int64
#  5   votes    5421 non-null   int64
#  6   country  5421 non-null   object
#  7   budget   5421 non-null   int64
#  8   gross    5421 non-null   int64
#  9   company  5421 non-null   object
#  10  runtime  5421 non-null   int64
# dtypes: int64(6), object(5)
# memory usage: 508.2+ KB
# None

# %%
"""Visual representaion of Genre and rating"""
sns.countplot(data=df, x='rating', hue='genre')
plt.legend(loc="upper right")
plt.title("Genre v/s Ratings")
plt.show()
'no. of counts of genre w.r.t ratings'
# Out:
# 'no. of counts of genre w.r.t ratings'

# %%
"""Visual representaion of Gross and budget"""
plt.scatter(df.budget, df.gross)
plt.title("Budget v/s Gross")
plt.xlabel("Budget")
plt.ylabel("Gross")
plt.show()
'The scatter graph concludes that as budget increases gross also increase'
'low budget movies have low profits'
# Out:
# 'low budget movies have low profits'

# %%
"""Visual representation of year and country"""
plt.bar(df.year, df.country)
plt.title("Year v/s Country")
plt.xlabel("Year")
plt.ylabel("Country")
plt.show()
'This graph shows in which countries the movies were released w.r.t Year '
# Out:
# 'This graph shows in which countries the movies were released w.r.t Year'

# %%
"Visual representation of country and runtime of movies"
plt.barh(df.country, df.runtime)
plt.xlabel("Country")
plt.ylabel("Runtime")
plt.title("Country v/s Runtime")
plt.show()
'highest runtime of movies is in United states and lowest runtime is in Israel'
# Out:
# 'highest runtime of movies is in United states and lowest runtime is in Israel'
